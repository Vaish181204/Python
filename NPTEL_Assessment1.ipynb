# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaish181204/Python/blob/main/NPTEL_Assessment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/flavors_of_cocoa (1).csv')

# %%
df.head()
# Out:
#    Id   Company  Bean Origin  Review Date Cocoa Percent Company Location  \
# 0   1  A. Morin  Agua Grande       2016.0           63%           France
# 1   2  A. Morin        Kpime       2015.0           70%           France
# 2   3  A. Morin       Atsane       2015.0           70%           France
# 3   4  A. Morin        Akata       2015.0           70%           France
# 4   5  A. Morin       Quilla       2015.0           70%           France
#
#    Rating
# 0    3.75
# 1    2.75
# 2    3.00
# 3    3.50
# 4    3.50

# %%
df.tail()
# Out:
#         Id Company         Bean Origin  Review Date Cocoa Percent  \
# 1790  1791  Zotter                Peru       2011.0           70%
# 1791  1792  Zotter               Congo       2011.0           65%
# 1792  1793  Zotter        Kerala State       2011.0           65%
# 1793  1794  Zotter        Kerala State       2011.0           62%
# 1794  1795  Zotter  Brazil, Mitzi Blue       2010.0           65%
#
#      Company Location  Rating
# 1790          Austria    3.75
# 1791          Austria    3.00
# 1792          Austria    3.50
# 1793          Austria    3.25
# 1794          Austria    3.00

# %%
#Q1 => To find null values
print(df.isnull().sum())
# Out:
# Id                  0
# Company             0
# Bean Origin         0
# Review Date         4
# Cocoa Percent       0
# Company Location    0
# Rating              0
# dtype: int64

# %% [markdown]
# ans => any id having value greater than 1 has null values

# %%
# Q2 => To find country with max locations
top_countries = df['Company Location'].value_counts().head(3)
print(top_countries)
# Out:
# Company Location
# U.S.A.    764
# France    156
# Canada    125
# Name: count, dtype: int64

# %%
# Q2 => To find country with max locations
top_countries = df['Company Location'].value_counts()
print(top_countries.head(1))
# Out:
# Company Location
# U.S.A.    764
# Name: count, dtype: int64

# %%
# Q3 => To check data conversion reuirements
print(df.dtypes)
print(df.info())
# Out:
# Id                    int64
# Company              object
# Bean Origin          object
# Review Date         float64
# Cocoa Percent        object
# Company Location     object
# Rating              float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1795 non-null   int64
#  1   Company           1795 non-null   object
#  2   Bean Origin       1795 non-null   object
#  3   Review Date       1791 non-null   float64
#  4   Cocoa Percent     1795 non-null   object
#  5   Company Location  1795 non-null   object
#  6   Rating            1795 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 98.3+ KB
# None

# %% [markdown]
# If any coloumn name has int64 it requires conversion

# %%
# Q4 => To find max rating
max_rating = df['Rating'].max()
print(max_rating)
# Out:
# 5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1795 non-null   int64
#  1   Company           1795 non-null   object
#  2   Bean Origin       1795 non-null   object
#  3   Review Date       1791 non-null   float64
#  4   Cocoa Percent     1795 non-null   object
#  5   Company Location  1795 non-null   object
#  6   Rating            1795 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 98.3+ KB

# %%
B = [True, 2, 3.0, np.nan, "False"]
[type(i) for i in B]
# Out:
# [bool, int, float, float, str]

# %%
arr = np.array([1, 2, 3, 4, 5])
print(arr[::2])
# Out:
# [1 3 5]
